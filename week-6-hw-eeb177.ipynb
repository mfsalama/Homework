# %%
# Part 1:
#Note: the format![badge1](/home/eeb177-student/Desktop/Screenshot_python_syntax.png) 
#did not work for me for some reason so instead I used the format below.

# %%
from IPython.display import Image
Image(filename= '/home/eeb177-student/Desktop/Screenshot_python_syntax.png')

# %%
from IPython.display import Image
Image(filename= '/home/eeb177-student/Desktop/Screenshot_quiz_python_syntax.png')

# %%
from IPython.display import Image
Image(filename= '/home/eeb177-student/Desktop/Screenshot_strings_console_output.png')

# %%
from IPython.display import Image
Image(filename= '/home/eeb177-student/Desktop/Screenshot_conditionals_control_flow.png')

# %%
from IPython.display import Image
Image(filename= '/home/eeb177-student/Desktop/Screenshot_functions.png')

# %%
from IPython.display import Image
Image(filename= '/home/eeb177-student/Desktop/Screenshot_python_lists_and_dictionaries.png')

# %%
from IPython.display import Image
Image(filename= '/home/eeb177-student/Desktop/Screenshot_lists_and_functions.png')

# %%
from IPython.display import Image
Image(filename= '/home/eeb177-student/Desktop/Screenshot_loops.png')

# %%
from IPython.display import Image
Image(filename= '/home/eeb177-student/Desktop/Screenshot_practice_makes_perfect.png')
